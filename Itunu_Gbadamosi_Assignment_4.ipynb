# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/messy_data.csv')
df
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# ...        ...         ...      ...      ...       ...     ...     ...
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06          NaN         87
# ...

# %%
df.shape
# Out:
# (10100, 10)

# %%
df.head()
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
df.TrnsnID.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10095    False
# 10096    False
# 10097    False
# 10098    False
# 10099    False
# Name: TrnsnID, Length: 10100, dtype: bool

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10095    False
# 10096    False
# 10097    False
# 10098    False
# 10099    False
# Length: 10100, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 100

# %%
df.loc[df.duplicated(keep = 'last'), :]
# Out:
#       TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 16        108  10/21/2030      643     1042       NaN       6  181.82
# 20        800  02-12-2023      480     1060    Book I       9   77.26
# 53       5548  01-05-2030      310     1018    Book D      -5   73.30
# 57       1057  04-10-2034      138     1086    Book T       5   94.21
# 65        577  03/21/2036      167     1024    Book K      14   92.09
# ...       ...         ...      ...      ...       ...     ...     ...
# 5963     7943  07/08/2029      881     1004     Boo E      11   87.23
# 6503     8188  08/19/2035      814     1019       NaN       5  188.77
# 6618     7439  26-03-2033      166     1036    Book I      17    7.37
# 7902     8285  01/05/2036      220     1047    Book G      16  185.09
# 8211     8576  03-06-2028      415     1001    Book T      14  184.67
#
#       TtlSales  PaymentType  CusterAge
# 16     4077.67   debit card         87
# 20     2032.76          NaN         53
# ...

# %%
df.drop_duplicates(keep = 'last', inplace = True)
df
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402  03/17/2026         991       1045       Boo E         9
# 1               5835  26-01-2035         741       1040      Book J        18
# 2               2123  05/26/2035         933       1062       Bok N         5
# 3               8789  28-02-2036         641       1060      Book I         6
# 4                305  19-04-2023         123       1058      Book B        15
# ...              ...         ...         ...        ...         ...       ...
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
# ...

# %%
df.head()
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
df.tail()
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 10095   2788.25  Credit Card         91
# 10096   1187.53       paypal         50
# 10097   2119.76   debit card         63
# 10098   1708.87        Debit         -7
# 10099   2743.67   debit card         77

# %%
df.isnull()
# Out:
#        TrnsnID   Data  CusmrID  ProdtID  ProdtName  Qutity  Prize  TtlSales  \
# 0        False  False    False    False      False   False  False     False
# 1        False  False    False    False      False   False  False     False
# 2        False  False    False    False      False   False  False     False
# 3        False  False    False    False      False   False  False     False
# 4        False  False    False    False      False   False  False     False
# ...        ...    ...      ...      ...        ...     ...    ...       ...
# 10095    False  False    False    False      False   False  False     False
# 10096    False  False    False    False      False   False  False     False
# 10097    False  False    False    False      False   False  False     False
# 10098    False  False    False    False      False   False  False     False
# 10099    False  False    False    False      False   False  False     False
#
#        PaymentType  CusterAge
# ...

# %%
df.isnull().sum()
# Out:
# TrnsnID           0
# Data              0
# CusmrID           0
# ProdtID           0
# ProdtName      1002
# Qutity            0
# Prize             0
# TtlSales          0
# PaymentType    1455
# CusterAge         0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# TrnsnID        10100
# Data           10100
# CusmrID        10100
# ProdtID        10100
# ProdtName       9098
# Qutity         10100
# Prize          10100
# TtlSales       10100
# PaymentType     8645
# CusterAge      10100
# dtype: int64

# %%
df.head()
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
df.dtypes
# Out:
# TrnsnID          int64
# Data            object
# CusmrID          int64
# ProdtID          int64
# ProdtName       object
# Qutity           int64
# Prize          float64
# TtlSales       float64
# PaymentType     object
# CusterAge        int64
# dtype: object

# %%
df.head()
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
df.rename( columns = {"TrnsnID": "TransactionID", "Data": "Date", "CusmrID": "CustomerID",  "ProdtID": "ProductID",
                      "ProdtName": "ProductName", "Qutity": "Quantity", "Prize": "Price", "TtlSales": "TotalSales",
                      "CusterAge": "CustomerAge"}, inplace = True)
df
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402  03/17/2026         991       1045       Boo E         9
# 1               5835  26-01-2035         741       1040      Book J        18
# 2               2123  05/26/2035         933       1062       Bok N         5
# 3               8789  28-02-2036         641       1060      Book I         6
# 4                305  19-04-2023         123       1058      Book B        15
# ...              ...         ...         ...        ...         ...       ...
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
# ...

# %%
df
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402  03/17/2026         991       1045       Boo E         9
# 1               5835  26-01-2035         741       1040      Book J        18
# 2               2123  05/26/2035         933       1062       Bok N         5
# 3               8789  28-02-2036         641       1060      Book I         6
# 4                305  19-04-2023         123       1058      Book B        15
# ...              ...         ...         ...        ...         ...       ...
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
# ...

# %%
#df['Date'] = pd.to_datetime(df['Date'], format = 'mixed')
#df

#df['Date'].dtype

# %%
df['PaymentType'].replace({"debit card": "Debit Card", "paypal" : "Paypal", "Debit" : "Debit Card"}, inplace = True)
df
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402  03/17/2026         991       1045       Boo E         9
# 1               5835  26-01-2035         741       1040      Book J        18
# 2               2123  05/26/2035         933       1062       Bok N         5
# 3               8789  28-02-2036         641       1060      Book I         6
# 4                305  19-04-2023         123       1058      Book B        15
# ...              ...         ...         ...        ...         ...       ...
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
# ...
